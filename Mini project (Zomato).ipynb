# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dff1=pd.read_csv('zomato.csv',encoding='latin1')
dff1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
dff2=pd.read_excel('Country-Code.xlsx')
dff2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %% [markdown]
# # Now we will merge the two datasets

# %%
dff3 = pd.merge(dff1,dff2,on='Country Code',how='left')
dff3
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# # Now let us check the names of all columns in our dataset

# %%
dff3.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# ## Checking null values in our dataset

# %%
dff3.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# ## List of countries the survey is spread across

# %%
for x in dff3['Country'].unique(): 
    print(x)
# Out:
# Phillipines
# Brazil
# United States
# Australia
# Canada
# Singapore
# UAE
# India
# Indonesia
# New Zealand
# United Kingdom
# Qatar
# South Africa
# Sri Lanka
# Turkey

# %%
len(dff3['Country'].unique())
# Out:
# 15

# %% [markdown]
# ## New Column Addding

# %%
dff3['new rating'] = dff3['Aggregate rating']*2
dff3.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ## Top 10 most available cuisines served by the restraunts

# %%
dff3['Cuisines'].value_counts().head(10)
# Out:
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64

# %%
dff4 = dff3['City']=='Kolkata'
dff3[dff4]
# Out:
#       Restaurant ID                 Restaurant Name  Country Code     City  \
# 2398       18217475  Asia Kitchen by Mainland China             1  Kolkata
# 2399       18249144                       Hoppipola             1  Kolkata
# 2400       18017612                     Spice Kraft             1  Kolkata
# 2401       18377112                        Nawwarah             1  Kolkata
# 2402          20002              6 Ballygunge Place             1  Kolkata
# 2403       18343731                    Mumbai Local             1  Kolkata
# 2404          25664          Gabbar's Bar & Kitchen             1  Kolkata
# 2405          25587                    TGI Friday's             1  Kolkata
# 2406          24530                Santa's Fantasea             1  Kolkata
# 2407          20747                India Restaurant             1  Kolkata
# 2408          21220                   Flame & Grill             1  Kolkata
# ...

# %% [markdown]
# ## Understanding the Rating aggregate, color and text

# %%
df3 = dff3.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
df3
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# # From above we observe that
# * Rating 0 — White — Not rated
# * Rating 1.8 to 2.4 — Red — Poor
# * Rating 2.5 to 3.4 — Orange — Average
# * Rating 3.5 to 3.9 — Yellow — Good
# * Rating 4.0 to 4.4 — Green — Very Good
# * Rating 4.5 to 4.9 — Dark Green — Excellent

# %%
plt.figure(figsize=(12,6))
plt.title('Rating Color')
sns.barplot(x=df3['Rating color'], y=df3['Rating Count'])
plt.show()

# %% [markdown]
# Maximum restaurants seems to have gone No ratings

# %%
No_rating = dff3[dff3['Rating color']=='White'].groupby('Country').size().reset_index().rename(columns={0:'Rating Count'})
No_rating
# Out:
#           Country  Rating Count
# 0          Brazil             5
# 1           India          2139
# 2  United Kingdom             1
# 3   United States             3

# %%
plt.figure(figsize=(12,6))
plt.title('Online Delivery Distribution')
plt.pie(dff3['Has Online delivery'].value_counts()/9551*100, labels=dff3['Has Online delivery'].value_counts().index, autopct='%1.2f%%');

# %% [markdown]
# # From which Locality maximum hotels are listed in Zomato

# %%
abc=dff3[(dff3.Country == 'India')]
abc
# Out:
#       Restaurant ID                        Restaurant Name  Country Code  \
# 624         3400025                             Jahanpanah             1
# 625         3400341                    Rangrezz Restaurant             1
# 626         3400005                Time2Eat - Mama Chicken             1
# 627         3400021  Chokho Jeeman Marwari Jain Bhojanalya             1
# 628         3400017                         Pinch Of Spice             1
# ...             ...                                    ...           ...
# 9271        2800100                               D Cabana             1
# 9272        2800418                               Kaloreez             1
# 9273        2800881                                Plot 17             1
# 9274        2800042                       Vista - The Park             1
# 9275        2800019               Flying Spaghetti Monster             1
#
#        City                                            Address  \
# ...

# %%
dff3['City'].unique()
# Out:
# array(['Makati City', 'Mandaluyong City', 'Pasay City', 'Pasig City',
#        'Quezon City', 'San Juan City', 'Santa Rosa', 'Tagaytay City',
#        'Taguig City', 'Brasí_lia', 'Rio de Janeiro', 'Sí£o Paulo',
#        'Albany', 'Armidale', 'Athens', 'Augusta', 'Balingup',
#        'Beechworth', 'Boise', 'Cedar Rapids/Iowa City', 'Chatham-Kent',
#        'Clatskanie', 'Cochrane', 'Columbus', 'Consort', 'Dalton',
#        'Davenport', 'Des Moines', 'Dicky Beach', 'Dubuque',
#        'East Ballina', 'Fernley', 'Flaxton', 'Forrest', 'Gainesville',
#        'Hepburn Springs', 'Huskisson', 'Inverloch', 'Lakes Entrance',
#        'Lakeview', 'Lincoln', 'Lorn', 'Macedon', 'Macon', 'Mayfield',
#        'Mc Millan', 'Middleton Beach', 'Miller', 'Monroe', 'Montville',
#        'Ojo Caliente', 'Orlando', 'Palm Cove', 'Paynesville', 'Penola',
#        'Pensacola', 'Phillip Island', 'Pocatello', 'Potrero', 'Princeton',
#        'Rest of Hawaii', 'Savannah', 'Singapore', 'Sioux City',
# ...

# %%
Delhi=dff3[(dff3.City == 'New Delhi')]
Delhi.Locality.value_counts().head(10)
# Out:
# Connaught Place        122
# Rajouri Garden          99
# Shahdara                87
# Defence Colony          86
# Pitampura               85
# Malviya Nagar           84
# Mayur Vihar Phase 1     84
# Rajinder Nagar          81
# Safdarjung              80
# Satyaniketan            79
# Name: Locality, dtype: int64

# %%
Delhi = dff3[(dff3.City == 'New Delhi')]
plt.figure(figsize=(12,6))
sns.barplot(x=Delhi.Locality.value_counts().head(10), y=Delhi.Locality.value_counts().head(10).index)
plt.ylabel(None)
plt.xlabel('Number of Resturants')
plt.title('Resturants Listing on Zomato')
plt.show()

# %% [markdown]
# Connaught place seems to have high no of restaurants registered with Zomato

# %%
Kolkata=dff3[(dff3.City == 'Kolkata')]
Kolkata.Locality.value_counts().head(10)
# Out:
# Ballygunge                       4
# Park Street Area                 4
# Acropolis Mall, Kasba            2
# Sector 5, Salt Lake              2
# Camac Street Area                1
# Elgin                            1
# Golpark                          1
# Kidderpore                       1
# Mani Square Mall, Kankurgachi    1
# Quest Mall, Ballygunge           1
# Name: Locality, dtype: int64

# %%
Kolkata = dff3[(dff3.City == 'Kolkata')]
plt.figure(figsize=(12,6))
sns.barplot(x=Kolkata.Locality.value_counts().head(10), y=Kolkata.Locality.value_counts().head(10).index)
plt.ylabel(None)
plt.xlabel('Number of Resturants')
plt.title('Resturants Listing on Zomato')
plt.show()

# %% [markdown]
# Here Ballygunge and Park Street Area seems to have high no. of restraunts registered on Zomato.

# %%
Nagpur=dff3[(dff3.City == 'Nagpur')]
Nagpur.Locality.value_counts().head(10)
# Out:
# Bajaj Nagar         5
# Civil Lines         3
# Dharampeth          3
# Sitabuldi           3
# Dhantoli            1
# Mohan Nagar         1
# Pratap Nagar        1
# Ramdaspeth          1
# Sadar               1
# Vivekanand Nagar    1
# Name: Locality, dtype: int64

# %%
Nagpur = dff3[(dff3.City == 'Nagpur')]
plt.figure(figsize=(12,6))
sns.barplot(x=Nagpur.Locality.value_counts().head(10), y=Nagpur.Locality.value_counts().head(10).index)
plt.ylabel(None)
plt.xlabel('Number of Resturants')
plt.title('Resturants Listing on Zomato')
plt.show()

# %%
plt.figure(figsize=(9,8))
sns.barplot(x='Aggregate rating',y='Votes',data=dff3)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Votes'>
